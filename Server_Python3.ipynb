# %%
PORT = 10025

# %%
import socket
import sys
import time
from threading import Thread 


class ClientThread(Thread): 
 
    def __init__(self,conn, ip,port): 
        Thread.__init__(self) 
        self.ip = ip 
        self.port = port 
        self.conn=conn
        #print "[+] New server socket thread started for " + ip + ":" + str(port) 
 
    def run(self): 
        a=1
        while a==1:
            data =  self.conn.recv(2048) 
            print ("\nServer received data:"+ data.decode())
            MESSAGEINICIO = "\n\tSERVIDOR: INICIANDO (self.port  "+str(self.port)+"): "+ data.decode('utf-8')
            MESSAGEFINAL = "\n\t\tSERVIDOR: TERMINANDO ("+str(self.port)+"): "+ data.decode('utf-8')
            if MESSAGEFINAL == 'exit':
                break
            try:
                print("\nTrying to send " + MESSAGEINICIO)
                self.conn.send(str.encode(MESSAGEINICIO) ) # echo
                self.conn.send(str.encode( "\n\t------SERVIDOR: CORRIENDO ("+str(self.port)+")") ) # echo
                time.sleep(1)
                print("\nTrying to send " + MESSAGEFINAL)
                self.conn.send(str.encode(MESSAGEFINAL) )  # echo 
                self.conn.close()
                a=0
            except:
                a=0
                print("ERROR ERROR ERROR")


# Create a TCP/IP socket
sock = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# Bind the socket to the port
server_address = ('localhost', PORT)
#print >>sys.stderr, 'starting up on %s port %s' % server_address
sock.bind(server_address)

threads=[]
# Listen for incoming connections
while True:
    sock.listen(100)
    (conn, (ip,port)) = sock.accept()
    newthread = ClientThread(conn, ip,port) 
    newthread.start() 
    threads.append(newthread) 	

for t in threads: 
    t.join()
# Out:
# Server received data:User: 6
# Server received data:User: 0
#
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45548): User: 6
# Trying to send
# SERVIDOR: INICIANDO (self.port  45546): User: 0
#
#
# Server received data:User: 7
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45550): User: 7
#
# Server received data:User: 5
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45552): User: 5
#
# Server received data:User: 4
# Server received data:User: 3
# Server received data:User: 9
#
#
# Server received data:User: 10
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45554): User: 4
# Trying to send
# SERVIDOR: INICIANDO (self.port  45556): User: 3
#
# Server received data:User: 11
# Server received data:User: 8
# Trying to send
# SERVIDOR: INICIANDO (self.port  45558): User: 9
#
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45560): User: 10
#
#
# Server received data:User: 1
# Server received data:User: 12
# Server received data:User: 13
#
#
# Server received data:User: 2
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45562): User: 11
# Trying to send
# SERVIDOR: INICIANDO (self.port  45564): User: 8
#
#
# Server received data:User: 14
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45570): User: 13
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45568): User: 12
#
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45566): User: 1
# Trying to send
# SERVIDOR: INICIANDO (self.port  45574): User: 14
#
# Trying to send
# SERVIDOR: INICIANDO (self.port  45572): User: 2
#
#
#
#
# Trying to send
# 		SERVIDOR: TERMINANDO (45550): User: 7
# Trying to send
# 		SERVIDOR: TERMINANDO (45546): User: 0
# Trying to send
# 		SERVIDOR: TERMINANDO (45548): User: 6
#
#
# Trying to send
# 		SERVIDOR: TERMINANDO (45556): User: 3
# Trying to send
# 		SERVIDOR: TERMINANDO (45552): User: 5
# Trying to send
# 		SERVIDOR: TERMINANDO (45554): User: 4
# Trying to send
# 		SERVIDOR: TERMINANDO (45560): User: 10
# Trying to send
# 		SERVIDOR: TERMINANDO (45558): User: 9
# Trying to send
# 		SERVIDOR: TERMINANDO (45572): User: 2
# Trying to send
# 		SERVIDOR: TERMINANDO (45570): User: 13
# Trying to send
# 		SERVIDOR: TERMINANDO (45562): User: 11
# Trying to send
# 		SERVIDOR: TERMINANDO (45566): User: 1
# Trying to send
# 		SERVIDOR: TERMINANDO (45574): User: 14
# Trying to send
# 		SERVIDOR: TERMINANDO (45564): User: 8
# Trying to send
# 		SERVIDOR: TERMINANDO (45568): User: 12
